# %%
import scipy.io
import matplotlib.pyplot as plt
import numpy as np
mat = scipy.io.loadmat('matlab.mat')
x = mat['skiraw'][:,0].real
patches = plt.hist(x, bins=20)
plt.show()
l = 1
x=np.linspace(-100, 100)

w = l*np.exp(-l*x)
p = np.cumsum(w* dx)
m = np.sum(w*x* dx)
d = np.sum(w*(x-m)**2* dx)


plt.plot(x,w) 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 12
#       9 x=np.linspace(-100, 100)
#      11 w = l*np.exp(-l*x)
# ---> 12 p = np.cumsum(w* dx)
#      13 m = np.sum(w*x* dx)
#      14 d = np.sum(w*(x-m)**2* dx)
#
# NameError: name 'dx' is not defined
